# %% [markdown]
# ## Student Details
#
# 195448
# Zalameda
# 2 BS ITE

# %% [markdown]
# ### First Problem
#
# In a prototype of a new in-campus mobile app, there is social media support similar to what's seen on Facebook, Instagram and Spotify. Students and Faculty belong to the same social graph. Any student or teacher can follow other members of the app community. If two members follow each other, they are considered friends.
#
# Write a function relationship_status(from_member, to_member) that determines if two members are friends, or if the first person follows or is followed by the second person. The function should return one of these:
#
# * "follower" (type is str)
# * "followed by"(type is str)
# * None (type is None)

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

from_member = input("Enter username: ")
to_member = input("Enter other username: ")

def relationship_status(from_member, to_member):
    from_user_followings = social_graph[from_member]["following"]
    to_user_followings = social_graph[to_member]["following"]
    
    if from_member in to_user_followings and to_member in from_user_followings:
        status = "friends"
        
    elif from_member in to_user_followings:
        status = "followed by"
        
    elif to_member in from_user_followings:
        status = "follows"
    
    else:
        status = "   "
        
    return status
        
print("Relationship Status: ", relationship_status(from_member, to_member))
# Out:
# Enter username: @jobenilagan
# Enter other username: @joeilagan
# Relationship Status:  friends

# %% [markdown]
# ### Second Problem
#
# Write code that checks a possible winner for the current state of a 3x3 tic-tac-toe board.
#
# There are several strategies here:
#
# * check if any symbol has all three slots in any row, column, or any of the two diagonals
# * create a set for each row, column and diagonal; if the set count of 1 indicates a winner. (Why?)

# %%
tictacboard = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

# Horizontal
print([t=='X' for t in tictacboard])

# Vertical

vertical = [t for t in zip(*tictacboard)]

print(all([t=='X' for t in zip(*tictacboard)]))

# Diagonal up - down X, X, X

tictacboard[0][0]
tictacboard[1][1]
tictacboard[2][2]

print(all([tictacboard[t][t]=='X' for t,b in enumerate(tictacboard)]))
    
# Diagonal down - up O, X, O

tictacboard[2][0]
tictacboard[1][1]
tictacboard[0][2]

print(all([tictacboard[2-t][t]=='X' for t,b in enumerate(tictacboard)]))
# Out:
# [False, False, False]
# False
# True
# False

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

def get_winner(board):
    
    i = 0
    
    column = [t[i] for t in board]
    updown = [board[i][i]=='X' for i,b in enumerate(board)]
    downup = [board[2-i][i]=='0' for i,b in enumerate(board)]
        
    # Horizontal
    while i in board:
        if board[i] == ['X','X','X']: 
            return "X"

        elif board[i] == ['O','O','O']:
            return "O"

    # Vertical

        elif column == ['X','X','X']:
            return "X"

        elif column == ['O','O','O']:
            return "O"

    # Diagonal up - down X, X, X
        elif updown == ['X','X','X']:
            return "X"

        elif updown == ['O','O','O']:
            return "O"

    # Diagonal down - up O, X, O
        elif downup == ['X','X','X']:
            return "X"

        elif downup == ['O','O','O']:
            return "O"
        
        else:
            i = i + 1
    
    
print(get_winner(board1))

# A for effort because I really tried but my brain hurts na thank u sir
# Out:
# None

# %% [markdown]
# ### Third Problem
#
# During the pandemic, a shuttle van service is tasked to travel along a predefined circular route as follows:
#
# * UP Diliman->Ateneo de Manila (Estimated Time: 10 mins)
# * Ateneo de Manila->De La Salle Taft (Estimated Time: 35 mins)
# * De La Salle Taft->UP Diliman (Estimated Time: 55 mins)
#
# The route is one-way only. So, the van cannot go back directly to UP Diliman from Ateneo de Manila; rather, it will have to drop by De La Salle Taft first before going to UP Diliman.
#
# Write a function called eta that accepts the source and destination of the van and returns the estimated number of minutes to reach the destination.

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, 
    
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

source = input("Enter source: ")
destination = input("Enter source: ")

def eta(source, destination): 
    upd_admu = legs.get(("upd","admu"))["travel_time_mins"]
    admu_dlsu = legs.get(("admu","dlsu"))["travel_time_mins"]
    dlsu_upd = legs.get(("dlsu","upd"))["travel_time_mins"]
    
    if "upd" in source and "admu" in destination:
        traveltime = upd_admu
        
    elif "admu" in source and "dlsu" in destination:
        traveltime = admu_dlsu
    
    elif "dlsu" in source and "upd" in destination:
        traveltime = dlsu_upd
        
    elif "upd" in source and "dlsu" in destination:
        traveltime = upd_admu + admu_dlsu
        
    elif "admu" in source and "upd" in destination:
        traveltime = admu_dlsu + dlsu_upd

    elif "dlsu" in source and "admu" in destination:
        traveltime = dlsu_upd + upd_admu
    
    else:
        traveltime = "What are you even inputting???"
    
    return traveltime

print("ETA: ", eta(source, destination))
# Out:
# Enter source: dlsu
# Enter source: upd
# ETA:  55
